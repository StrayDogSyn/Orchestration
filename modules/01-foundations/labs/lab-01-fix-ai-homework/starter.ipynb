# %% [markdown]
# ---
#
# ## 🔧 The AI-Generated Code
#
# Here's what your teammate's AI produced. Run the cell below to load it into memory.

# %%
class JobTracker:
    """Track job applications for justice-impacted job seekers.
    
    Generated by: ChatGPT (according to your teammate)
    Review status: PENDING ARCHITECT REVIEW
    """
    
    def __init__(self):
        self.applications = []  # List of dicts
    
    def add_application(self, company, position, date):
        """Add a new job application"""
        self.applications.append({
            'company': company,
            'position': position,
            'date': date,
            'status': 'pending'
        })
    
    def find_by_company(self, company):
        """Find all applications to a specific company"""
        results = []
        for app in self.applications:
            if app['company'] == company:
                results.append(app)
        return results
    
    def update_status(self, company, position, new_status):
        """Update the status of a specific application"""
        for app in self.applications:
            if app['company'] == company and app['position'] == position:
                app['status'] = new_status
                return True
        return False
    
    def get_all(self):
        """Return all applications"""
        return self.applications


# Quick test to make sure it works
tracker = JobTracker()
tracker.add_application("Google", "Software Engineer", "2025-01-15")
tracker.add_application("Microsoft", "Data Scientist", "2025-01-16")
tracker.add_application("Google", "Product Manager", "2025-01-17")

print("✅ JobTracker loaded successfully!")
print(f"📋 Total applications: {len(tracker.get_all())}")
print(f"🔍 Google applications: {tracker.find_by_company('Google')}")

# %% [markdown]
# ---
#
# ## 📝 Task 1: Complexity Analysis (5 minutes)
#
# **Question**: If you have 1,000 applications in the system, what's the time complexity of calling `find_by_company("Google")`?
#
# **Hint**: How many applications does Python need to check in the worst case?
#
# ### Your Analysis
#
# Double-click this cell and write your answer below:
#
# **Time Complexity**: `O(___)`
#
# **Explanation** (in plain English):
# > *Your explanation here...*
#
# ---

# %% [markdown]
# ## 🔬 Task 2: Architect's Diagnosis (5 minutes)
#
# **Question**: What data structure would make `find_by_company()` run in O(1) time instead of O(n)?
#
# ### Your Diagnosis
#
# Double-click this cell and write your answer below:
#
# **Recommended Data Structure**: _______________
#
# **Why it's faster**:
# > *Your explanation here...*
#
# **Trade-off** (there's no free lunch in CS):
# > *What do we give up by using this approach?*
#
# ---

# %% [markdown]
# ## ✍️ Task 3: The Architect's Prompt (10 minutes)
#
# Now you'll prompt an AI to fix this—but like an architect, not a user.
#
# ### ❌ Example of a BAD Prompt:
# ```
# "Make find_by_company() faster"
# ```
#
# ### ✅ Example of a GOOD Prompt:
# ```
# "The find_by_company() method is currently O(n), which means it gets slower
# as more applications are added.
#
# Explain why this happens, then refactor the JobTracker class to use a
# dictionary (hash map) keyed by company name for O(1) lookups.
#
# After showing the refactored code, explain:
# 1. Why this is faster
# 2. What memory trade-off we're making
# 3. What happens if we need to support multiple applications to the same company"
# ```
#
# ### Your Task:
# 1. Write YOUR version of the architect's prompt in the cell below
# 2. Submit it to ChatGPT or Claude
# 3. Paste the AI's response in the following cell
# 4. Evaluate: Did it explain the WHY, or just give you code?

# %% [markdown]
# ### YOUR Architect's Prompt:
#
# ```
# Write your prompt here...
#
#
#
#
# ```

# %% [markdown]
# ### AI's Response:
#
# Paste the AI's response here:
#
# ```
#
#
#
#
#
# ```
#
# ---

# %% [markdown]
# ## 🧪 Task 4: Verification & Testing (8 minutes)
#
# **Don't just trust the AI's code—test it.**
#
# ### Step 1: Paste and run the AI's refactored code below

# %%
# PASTE THE AI'S REFACTORED JobTracker CLASS HERE
# (Replace this comment with the actual code)

class JobTrackerRefactored:
    """Paste the AI's improved version here"""
    pass

# %% [markdown]
# ### Step 2: Run the Performance Test
#
# Run the cell below to compare the original vs refactored versions.

# %%
import time

def test_performance(tracker_class, name, num_applications=1000):
    """Test the performance of a JobTracker implementation"""
    tracker = tracker_class()
    
    # Add many applications
    start = time.time()
    for i in range(num_applications):
        # Distribute across 100 companies
        company = f"Company_{i % 100}"
        tracker.add_application(company, f"Position_{i}", "2025-01-01")
    add_time = time.time() - start
    
    # Test lookup performance
    start = time.time()
    results = tracker.find_by_company("Company_42")
    lookup_time = time.time() - start
    
    print(f"\n{'='*50}")
    print(f"📊 {name}")
    print(f"{'='*50}")
    print(f"⏱️  Adding {num_applications} applications: {add_time:.4f} seconds")
    print(f"🔍 Lookup time: {lookup_time:.6f} seconds")
    print(f"📋 Found {len(results)} applications for Company_42")
    
    return add_time, lookup_time


# Test the ORIGINAL implementation
print("\n🧪 PERFORMANCE COMPARISON TEST")
print("Testing with 1,000 applications...\n")

original_add, original_lookup = test_performance(JobTracker, "ORIGINAL (List-based)")

# %%
# Test the REFACTORED implementation
# (This will error if you haven't pasted the AI's code above)

try:
    refactored_add, refactored_lookup = test_performance(
        JobTrackerRefactored, 
        "REFACTORED (Dictionary-based)"
    )
    
    # Show comparison
    print(f"\n{'='*50}")
    print("📈 COMPARISON SUMMARY")
    print(f"{'='*50}")
    
    if refactored_lookup < original_lookup:
        speedup = original_lookup / refactored_lookup if refactored_lookup > 0 else float('inf')
        print(f"✅ Refactored lookup is {speedup:.1f}x faster!")
    else:
        print(f"⚠️ Refactored version isn't faster. Check the implementation.")
        
except Exception as e:
    print(f"❌ Error testing refactored version: {e}")
    print("\n💡 Make sure you've pasted the AI's code in the cell above!")

# %% [markdown]
# ### Step 3: Scale Test (Optional Challenge)
#
# What happens when we scale to 10,000 applications? Run this to see the difference more dramatically.

# %%
# OPTIONAL: Run this to see the difference at scale
print("\n🚀 SCALE TEST: 10,000 applications")
print("(This may take a moment for the original implementation...)\n")

test_performance(JobTracker, "ORIGINAL at 10k", num_applications=10000)

try:
    test_performance(JobTrackerRefactored, "REFACTORED at 10k", num_applications=10000)
except:
    print("\n⚠️ Couldn't test refactored version - paste the code first!")

# %% [markdown]
# ---
#
# ## 🎯 Lab Deliverables
#
# Before marking this lab complete, ensure you have:
#
# - [ ] **Task 1**: Written your complexity analysis
# - [ ] **Task 2**: Identified the better data structure and trade-offs
# - [ ] **Task 3**: Written an architect-level prompt and received AI response
# - [ ] **Task 4**: Run the performance tests and verified the improvement
#
# ---

# %% [markdown]
# ## 💭 Final Reflection
#
# Answer these questions before closing this lab:
#
# ### Reflection 1: Prompt Quality
# > What did you learn about how the AI responds to specific vs vague prompts?
#
# *Your answer:*
#
#
# ### Reflection 2: Edge Cases
# > Did the AI catch the "multiple applications to same company" edge case, or did you have to ask?
#
# *Your answer:*
#
#
# ### Reflection 3: The Architect's Role
# > How would this lab have gone differently if you just asked the AI "build me a job tracker" without reviewing the code?
#
# *Your answer:*
#
# ---
#
# ## ✅ Lab Complete!
#
# **Congratulations!** You've completed your first exercise as an AI Architect.
#
# **Key Takeaway**: The AI wrote working code. But YOU identified it wouldn't scale, YOU crafted the prompt to fix it properly, and YOU verified the solution. That's orchestration.
#
# ---
#
# **Next**: Return to [Lecture 01](../../lectures/01-architects-advantage.md) to complete the reflection questions, then move on to Lecture 02.
